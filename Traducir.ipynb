# %%
# !pip install argostranslate
# Out:
# Collecting argostranslate
#   Downloading argostranslate-1.11.0-py3-none-any.whl.metadata (9.7 kB)
# Collecting ctranslate2<5,>=4.0 (from argostranslate)
#   Downloading ctranslate2-4.7.1-cp312-cp312-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl.metadata (10 kB)
# Collecting minisbd (from argostranslate)
#   Downloading minisbd-0.9.3-py3-none-any.whl.metadata (47 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 47.2/47.2 kB 4.3 MB/s eta 0:00:00
# Requirement already satisfied: packaging in /usr/local/lib/python3.12/dist-packages (from argostranslate) (26.0)
# Collecting sacremoses<0.2,>=0.0.53 (from argostranslate)
#   Downloading sacremoses-0.1.1-py3-none-any.whl.metadata (8.3 kB)
# Requirement already satisfied: sentencepiece<0.3,>=0.2.0 in /usr/local/lib/python3.12/dist-packages (from argostranslate) (0.2.1)
# Requirement already satisfied: spacy in /usr/local/lib/python3.12/dist-packages (from argostranslate) (3.8.11)
# Collecting stanza==1.10.1 (from argostranslate)
#   Downloading stanza-1.10.1-py3-none-any.whl.metadata (13 kB)
# Collecting emoji (from stanza==1.10.1->argostranslate)
#   Downloading emoji-2.15.0-py3-none-any.whl.metadata (5.7 kB)
# Requirement already satisfied: numpy in /usr/local/lib/python3.12/dist-packages (from stanza==1.10.1->argostranslate) (2.0.2)
# Requirement already satisfied: protobuf>=3.15.0 in /usr/local/lib/python3.12/dist-packages (from stanza==1.10.1->argostranslate) (5.29.6)
# Requirement already satisfied: requests in /usr/local/lib/python3.12/dist-packages (from stanza==1.10.1->argostranslate) (2.32.4)
# Requirement already satisfied: networkx in /usr/local/lib/python3.12/dist-packages (from stanza==1.10.1->argostranslate) (3.6.1)
# Requirement already satisfied: torch>=1.3.0 in /usr/local/lib/python3.12/dist-packages (from stanza==1.10.1->argostranslate) (2.10.0+cu128)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.12/dist-packages (from stanza==1.10.1->argostranslate) (4.67.3)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.12/dist-packages (from ctranslate2<5,>=4.0->argostranslate) (75.2.0)
# Requirement already satisfied: pyyaml<7,>=5.3 in /usr/local/lib/python3.12/dist-packages (from ctranslate2<5,>=4.0->argostranslate) (6.0.3)
# Requirement already satisfied: regex in /usr/local/lib/python3.12/dist-packages (from sacremoses<0.2,>=0.0.53->argostranslate) (2025.11.3)
# Requirement already satisfied: click in /usr/local/lib/python3.12/dist-packages (from sacremoses<0.2,>=0.0.53->argostranslate) (8.3.1)
# Requirement already satisfied: joblib in /usr/local/lib/python3.12/dist-packages (from sacremoses<0.2,>=0.0.53->argostranslate) (1.5.3)
# Requirement already satisfied: filelock>=3.16.1 in /usr/local/lib/python3.12/dist-packages (from minisbd->argostranslate) (3.24.3)
# Collecting onnxruntime>=1.10.0 (from minisbd->argostranslate)
#   Downloading onnxruntime-1.24.2-cp312-cp312-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl.metadata (5.0 kB)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.11 in /usr/local/lib/python3.12/dist-packages (from spacy->argostranslate) (3.0.12)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in /usr/local/lib/python3.12/dist-packages (from spacy->argostranslate) (1.0.5)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /usr/local/lib/python3.12/dist-packages (from spacy->argostranslate) (1.0.15)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /usr/local/lib/python3.12/dist-packages (from spacy->argostranslate) (2.0.13)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /usr/local/lib/python3.12/dist-packages (from spacy->argostranslate) (3.0.12)
# Requirement already satisfied: thinc<8.4.0,>=8.3.4 in /usr/local/lib/python3.12/dist-packages (from spacy->argostranslate) (8.3.10)
# Requirement already satisfied: wasabi<1.2.0,>=0.9.1 in /usr/local/lib/python3.12/dist-packages (from spacy->argostranslate) (1.1.3)
# Requirement already satisfied: srsly<3.0.0,>=2.4.3 in /usr/local/lib/python3.12/dist-packages (from spacy->argostranslate) (2.5.2)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in /usr/local/lib/python3.12/dist-packages (from spacy->argostranslate) (2.0.10)
# Requirement already satisfied: weasel<0.5.0,>=0.4.2 in /usr/local/lib/python3.12/dist-packages (from spacy->argostranslate) (0.4.3)
# Requirement already satisfied: typer-slim<1.0.0,>=0.3.0 in /usr/local/lib/python3.12/dist-packages (from spacy->argostranslate) (0.24.0)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4 in /usr/local/lib/python3.12/dist-packages (from spacy->argostranslate) (2.12.3)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.12/dist-packages (from spacy->argostranslate) (3.1.6)
# Requirement already satisfied: flatbuffers in /usr/local/lib/python3.12/dist-packages (from onnxruntime>=1.10.0->minisbd->argostranslate) (25.12.19)
# Requirement already satisfied: sympy in /usr/local/lib/python3.12/dist-packages (from onnxruntime>=1.10.0->minisbd->argostranslate) (1.14.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.12/dist-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy->argostranslate) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.4 in /usr/local/lib/python3.12/dist-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy->argostranslate) (2.41.4)
# Requirement already satisfied: typing-extensions>=4.14.1 in /usr/local/lib/python3.12/dist-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy->argostranslate) (4.15.0)
# Requirement already satisfied: typing-inspection>=0.4.2 in /usr/local/lib/python3.12/dist-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy->argostranslate) (0.4.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests->stanza==1.10.1->argostranslate) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests->stanza==1.10.1->argostranslate) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests->stanza==1.10.1->argostranslate) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests->stanza==1.10.1->argostranslate) (2026.1.4)
# Requirement already satisfied: blis<1.4.0,>=1.3.0 in /usr/local/lib/python3.12/dist-packages (from thinc<8.4.0,>=8.3.4->spacy->argostranslate) (1.3.3)
# Requirement already satisfied: confection<1.0.0,>=0.0.1 in /usr/local/lib/python3.12/dist-packages (from thinc<8.4.0,>=8.3.4->spacy->argostranslate) (0.1.5)
# Requirement already satisfied: fsspec>=0.8.5 in /usr/local/lib/python3.12/dist-packages (from torch>=1.3.0->stanza==1.10.1->argostranslate) (2025.3.0)
# Requirement already satisfied: cuda-bindings==12.9.4 in /usr/local/lib/python3.12/dist-packages (from torch>=1.3.0->stanza==1.10.1->argostranslate) (12.9.4)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.8.93 in /usr/local/lib/python3.12/dist-packages (from torch>=1.3.0->stanza==1.10.1->argostranslate) (12.8.93)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.8.90 in /usr/local/lib/python3.12/dist-packages (from torch>=1.3.0->stanza==1.10.1->argostranslate) (12.8.90)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.8.90 in /usr/local/lib/python3.12/dist-packages (from torch>=1.3.0->stanza==1.10.1->argostranslate) (12.8.90)
# Requirement already satisfied: nvidia-cudnn-cu12==9.10.2.21 in /usr/local/lib/python3.12/dist-packages (from torch>=1.3.0->stanza==1.10.1->argostranslate) (9.10.2.21)
# Requirement already satisfied: nvidia-cublas-cu12==12.8.4.1 in /usr/local/lib/python3.12/dist-packages (from torch>=1.3.0->stanza==1.10.1->argostranslate) (12.8.4.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.3.3.83 in /usr/local/lib/python3.12/dist-packages (from torch>=1.3.0->stanza==1.10.1->argostranslate) (11.3.3.83)
# Requirement already satisfied: nvidia-curand-cu12==10.3.9.90 in /usr/local/lib/python3.12/dist-packages (from torch>=1.3.0->stanza==1.10.1->argostranslate) (10.3.9.90)
# Requirement already satisfied: nvidia-cusolver-cu12==11.7.3.90 in /usr/local/lib/python3.12/dist-packages (from torch>=1.3.0->stanza==1.10.1->argostranslate) (11.7.3.90)
# Requirement already satisfied: nvidia-cusparse-cu12==12.5.8.93 in /usr/local/lib/python3.12/dist-packages (from torch>=1.3.0->stanza==1.10.1->argostranslate) (12.5.8.93)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.7.1 in /usr/local/lib/python3.12/dist-packages (from torch>=1.3.0->stanza==1.10.1->argostranslate) (0.7.1)
# Requirement already satisfied: nvidia-nccl-cu12==2.27.5 in /usr/local/lib/python3.12/dist-packages (from torch>=1.3.0->stanza==1.10.1->argostranslate) (2.27.5)
# Requirement already satisfied: nvidia-nvshmem-cu12==3.4.5 in /usr/local/lib/python3.12/dist-packages (from torch>=1.3.0->stanza==1.10.1->argostranslate) (3.4.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.8.90 in /usr/local/lib/python3.12/dist-packages (from torch>=1.3.0->stanza==1.10.1->argostranslate) (12.8.90)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.8.93 in /usr/local/lib/python3.12/dist-packages (from torch>=1.3.0->stanza==1.10.1->argostranslate) (12.8.93)
# Requirement already satisfied: nvidia-cufile-cu12==1.13.1.3 in /usr/local/lib/python3.12/dist-packages (from torch>=1.3.0->stanza==1.10.1->argostranslate) (1.13.1.3)
# Requirement already satisfied: triton==3.6.0 in /usr/local/lib/python3.12/dist-packages (from torch>=1.3.0->stanza==1.10.1->argostranslate) (3.6.0)
# Requirement already satisfied: cuda-pathfinder~=1.1 in /usr/local/lib/python3.12/dist-packages (from cuda-bindings==12.9.4->torch>=1.3.0->stanza==1.10.1->argostranslate) (1.3.5)
# Requirement already satisfied: typer>=0.24.0 in /usr/local/lib/python3.12/dist-packages (from typer-slim<1.0.0,>=0.3.0->spacy->argostranslate) (0.24.1)
# Requirement already satisfied: cloudpathlib<1.0.0,>=0.7.0 in /usr/local/lib/python3.12/dist-packages (from weasel<0.5.0,>=0.4.2->spacy->argostranslate) (0.23.0)
# Requirement already satisfied: smart-open<8.0.0,>=5.2.1 in /usr/local/lib/python3.12/dist-packages (from weasel<0.5.0,>=0.4.2->spacy->argostranslate) (7.5.1)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.12/dist-packages (from jinja2->spacy->argostranslate) (3.0.3)
# Requirement already satisfied: wrapt in /usr/local/lib/python3.12/dist-packages (from smart-open<8.0.0,>=5.2.1->weasel<0.5.0,>=0.4.2->spacy->argostranslate) (2.1.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from sympy->onnxruntime>=1.10.0->minisbd->argostranslate) (1.3.0)
# Requirement already satisfied: shellingham>=1.3.0 in /usr/local/lib/python3.12/dist-packages (from typer>=0.24.0->typer-slim<1.0.0,>=0.3.0->spacy->argostranslate) (1.5.4)
# Requirement already satisfied: rich>=12.3.0 in /usr/local/lib/python3.12/dist-packages (from typer>=0.24.0->typer-slim<1.0.0,>=0.3.0->spacy->argostranslate) (13.9.4)
# Requirement already satisfied: annotated-doc>=0.0.2 in /usr/local/lib/python3.12/dist-packages (from typer>=0.24.0->typer-slim<1.0.0,>=0.3.0->spacy->argostranslate) (0.0.4)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.12/dist-packages (from rich>=12.3.0->typer>=0.24.0->typer-slim<1.0.0,>=0.3.0->spacy->argostranslate) (4.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.12/dist-packages (from rich>=12.3.0->typer>=0.24.0->typer-slim<1.0.0,>=0.3.0->spacy->argostranslate) (2.19.2)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.12/dist-packages (from markdown-it-py>=2.2.0->rich>=12.3.0->typer>=0.24.0->typer-slim<1.0.0,>=0.3.0->spacy->argostranslate) (0.1.2)
# Downloading argostranslate-1.11.0-py3-none-any.whl (41 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 41.6/41.6 kB 4.4 MB/s eta 0:00:00
# Downloading stanza-1.10.1-py3-none-any.whl (1.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 57.3 MB/s eta 0:00:00
# Downloading ctranslate2-4.7.1-cp312-cp312-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl (39.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 39.0/39.0 MB 18.2 MB/s eta 0:00:00
# Downloading sacremoses-0.1.1-py3-none-any.whl (897 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 897.5/897.5 kB 52.5 MB/s eta 0:00:00
# Downloading minisbd-0.9.3-py3-none-any.whl (40 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 40.9/40.9 kB 3.0 MB/s eta 0:00:00
# Downloading onnxruntime-1.24.2-cp312-cp312-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl (17.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 17.1/17.1 MB 75.9 MB/s eta 0:00:00
# Downloading emoji-2.15.0-py3-none-any.whl (608 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 608.4/608.4 kB 43.4 MB/s eta 0:00:00
# Installing collected packages: sacremoses, emoji, ctranslate2, onnxruntime, minisbd, stanza, argostranslate
# Successfully installed argostranslate-1.11.0 ctranslate2-4.7.1 emoji-2.15.0 minisbd-0.9.3 onnxruntime-1.24.2 sacremoses-0.1.1 stanza-1.10.1

# %%
import re
from pathlib import Path

import argostranslate.package
import argostranslate.translate


def _protect_markdown(text: str):
    """
    Protege segmentos que NO deben traducirse (bloques de código, inline code,
    URLs crudas, etc.) reemplazándolos por placeholders.
    """
    patterns = [
        # Bloques de código triple backtick
        (r"```[\s\S]*?```", "CODEBLOCK"),
        # Inline code `...`
        (r"`[^`\n]+`", "INLINECODE"),
        # URLs crudas
        (r"https?://[^\s)]+", "URL"),
    ]

    placeholders = []
    protected = text

    for pattern, tag in patterns:
        def repl(m):
            placeholders.append(m.group(0))
            return f"@@{tag}{len(placeholders)-1}@@"
        protected = re.sub(pattern, repl, protected)

    return protected, placeholders


def _unprotect_markdown(text: str, placeholders):
    """Restaura los placeholders a su contenido original."""
    def repl(m):
        idx = int(m.group(1))
        return placeholders[idx]
    return re.sub(r"@@[A-Z]+(\d+)@@", repl, text)


def ensure_argos_package(from_code="en", to_code="es"):
    """
    Descarga/instala el paquete de traducción Argos si no está instalado.
    (Requiere internet sólo para descargar el paquete la primera vez)
    """
    installed = argostranslate.translate.get_installed_languages()
    installed_codes = {lang.code for lang in installed}

    if from_code in installed_codes and to_code in installed_codes:
        # Podrían estar instalados pero no necesariamente el par; validamos luego.
        pass

    # Descarga el índice de paquetes y busca el par deseado
    argostranslate.package.update_package_index()
    available_packages = argostranslate.package.get_available_packages()

    pkg = next(
        (p for p in available_packages if p.from_code == from_code and p.to_code == to_code),
        None
    )
    if pkg is None:
        raise RuntimeError(f"No encontré paquete Argos para {from_code}->{to_code}.")

    # Instala
    download_path = pkg.download()
    argostranslate.package.install_from_path(download_path)


def translate_markdown(text: str, from_code="en", to_code="es") -> str:
    protected, placeholders = _protect_markdown(text)

    # Traduce todo lo protegido (con placeholders)
    translated = argostranslate.translate.translate(protected, from_code, to_code)

    # Restaura segmentos no traducibles
    restored = _unprotect_markdown(translated, placeholders)
    return restored


def main(
    input_md: str,
    output_md: str,
    from_code="en",
    to_code="es",
):
    in_path = Path(input_md)
    out_path = Path(output_md)

    md_text = in_path.read_text(encoding="utf-8")

    # Asegura modelo Argos
    ensure_argos_package(from_code=from_code, to_code=to_code)

    translated = translate_markdown(md_text, from_code=from_code, to_code=to_code)

    out_path.write_text(translated, encoding="utf-8")
    print(f"✅ Traducción guardada en: {out_path}")


if __name__ == "__main__":
    # Ejemplo:
    # main("input.md", "output_es.md", from_code="en", to_code="es")
    main("/content/L1_A4_English (1).md", "L1_A4_English_es.md", from_code="en", to_code="es")
# Out:
# Streaming output truncated to the last 5000 lines.
# INFO:argostranslate.utils:('tokenized', [['▁in', 'de', 'b', 'ted', 'ness', '.'], ['▁The', '▁attempt', '▁to', '▁imita', 'te', '▁the', '▁US', '▁banking', '▁system', '▁favor', 'ed', '▁an']])
# INFO:argostranslate.utils:('translated_batches', [TranslationResult(hypotheses=[['▁en', 'de', 'ud', 'amiento', '.']], scores=[-2.1035478115081787], attention=[], logits=[]), TranslationResult(hypotheses=[['▁El', '▁intento', '▁de', '▁imita', 'r', '▁el', '▁sistema', '▁bancario', '▁estadounidense', '▁favor', 'e', 'ció', '▁a', '▁un']], scores=[-2.980151653289795], attention=[], logits=[])])
# INFO:argostranslate.utils:('value_hypotheses:', [('endeudamiento. El intento de imitar el sistema bancario estadounidense favoreció a un', -5.083699464797974)])
# INFO:argostranslate.utils:('translated_paragraphs:', [[('endeudamiento. El intento de imitar el sistema bancario estadounidense favoreció a un', -5.083699464797974)]])
# INFO:argostranslate.utils:('hypotheses_to_return:', [('endeudamiento. El intento de imitar el sistema bancario estadounidense favoreció a un', -5.083699464797974)])
# INFO:argostranslate.utils:('paragraphs:', ['increase in money in circulation and in prices. The population became restive.'])
# INFO:argostranslate.utils:('apply_packaged_translation', 'increase in money in circulation and in prices. The population became restive.')
# INFO:argostranslate.utils:('Splitting sentences using SBD Model: (en) StanzaSentencizer',)
# INFO:argostranslate.utils:('sentences', ['increase in money in circulation and in prices.', 'The population became restive.'])
# INFO:argostranslate.utils:('tokenized', [['▁increase', '▁in', '▁money', '▁in', '▁circulation', '▁and', '▁in', '▁prices', '.'], ['▁The', '▁population', '▁became', '▁rest', 'ive', '.']])
# INFO:argostranslate.utils:('translated_batches', [TranslationResult(hypotheses=[['▁aumentar', '▁el', '▁dinero', '▁en', '▁circulación', '▁y', '▁en', '▁precios', '.']], scores=[-2.297811269760132], attention=[], logits=[]), TranslationResult(hypotheses=[['▁La', '▁población', '▁se', '▁volvió', '▁inquieta', '.']], scores=[-2.826850414276123], attention=[], logits=[])])
# INFO:argostranslate.utils:('value_hypotheses:', [('aumentar el dinero en circulación y en precios. La población se volvió inquieta.', -5.124661684036255)])
# INFO:argostranslate.utils:('translated_paragraphs:', [[('aumentar el dinero en circulación y en precios. La población se volvió inquieta.', -5.124661684036255)]])
# INFO:argostranslate.utils:('hypotheses_to_return:', [('aumentar el dinero en circulación y en precios. La población se volvió inquieta.', -5.124661684036255)])
# INFO:argostranslate.utils:('paragraphs:', ['In 1877 there was an attempt at revolution (the Satsuma Rebellion) and in'])
# INFO:argostranslate.utils:('apply_packaged_translation', 'In 1877 there was an attempt at revolution (the Satsuma Rebellion) and in')
# INFO:argostranslate.utils:('Splitting sentences using SBD Model: (en) StanzaSentencizer',)
# INFO:argostranslate.utils:('sentences', ['In 1877 there was an attempt at revolution (the Satsuma Rebellion) and in'])
# INFO:argostranslate.utils:('tokenized', [['▁In', '▁18', '77', '▁there', '▁was', '▁an', '▁attempt', '▁at', '▁revolution', '▁(', 'the', '▁Sa', 'tsu', 'ma', '▁Re', 'be', 'll', 'ion', ')', '▁and', '▁in']])
# INFO:argostranslate.utils:('translated_batches', [TranslationResult(hypotheses=[['▁En', '▁18', '77', '▁hubo', '▁un', '▁intento', '▁de', '▁revolución', '▁(', 'la', '▁rebelión', '▁de', '▁Sa', 'tsu', 'ma', ')', '▁y', '▁en']], scores=[-3.226252317428589], attention=[], logits=[])])
# INFO:argostranslate.utils:('value_hypotheses:', [('En 1877 hubo un intento de revolución (la rebelión de Satsuma) y en', -3.226252317428589)])
# INFO:argostranslate.utils:('translated_paragraphs:', [[('En 1877 hubo un intento de revolución (la rebelión de Satsuma) y en', -3.226252317428589)]])
# INFO:argostranslate.utils:('hypotheses_to_return:', [('En 1877 hubo un intento de revolución (la rebelión de Satsuma) y en', -3.226252317428589)])
# INFO:argostranslate.utils:('paragraphs:', ['1881 under the energetic direction of the prince Masayoshi Matsukata,'])
# INFO:argostranslate.utils:('apply_packaged_translation', '1881 under the energetic direction of the prince Masayoshi Matsukata,')
# INFO:argostranslate.utils:('Splitting sentences using SBD Model: (en) StanzaSentencizer',)
# INFO:argostranslate.utils:('sentences', ['1881 under the energetic direction of the prince Masayoshi Matsukata,'])
# INFO:argostranslate.utils:('tokenized', [['▁18', '81', '▁under', '▁the', '▁energetic', '▁direction', '▁of', '▁the', '▁prince', '▁Mas', 'a', 'yo', 'shi', '▁Mat', 's', 'uka', 'ta', ',']])
# INFO:argostranslate.utils:('translated_batches', [TranslationResult(hypotheses=[['▁18', '81', '▁bajo', '▁la', '▁dirección', '▁energética', '▁del', '▁príncipe', '▁Mas', 'a', 'yo', 'shi', '▁Mat', 's', 'uka', 'ta', ',']], scores=[-1.6175575256347656], attention=[], logits=[])])
# INFO:argostranslate.utils:('value_hypotheses:', [('1881 bajo la dirección energética del príncipe Masayoshi Matsukata,', -1.6175575256347656)])
# INFO:argostranslate.utils:('translated_paragraphs:', [[('1881 bajo la dirección energética del príncipe Masayoshi Matsukata,', -1.6175575256347656)]])
# INFO:argostranslate.utils:('hypotheses_to_return:', [('1881 bajo la dirección energética del príncipe Masayoshi Matsukata,', -1.6175575256347656)])
# INFO:argostranslate.utils:('paragraphs:', ['treasury Minister, a program of stabilization was initiated. Most state'])
# INFO:argostranslate.utils:('apply_packaged_translation', 'treasury Minister, a program of stabilization was initiated. Most state')
# INFO:argostranslate.utils:('Splitting sentences using SBD Model: (en) StanzaSentencizer',)
# INFO:argostranslate.utils:('sentences', ['treasury Minister, a program of stabilization was initiated.', 'Most state'])
# INFO:argostranslate.utils:('tokenized', [['▁tre', 'a', 'sur', 'y', '▁Minister', ',', '▁a', '▁program', '▁of', '▁stabilization', '▁was', '▁initiated', '.'], ['▁Most', '▁state']])
# INFO:argostranslate.utils:('translated_batches', [TranslationResult(hypotheses=[['▁Ministro', '▁de', '▁Hacienda', ',', '▁se', '▁inició', '▁un', '▁programa', '▁de', '▁estabilización', '.']], scores=[-1.95171058177948], attention=[], logits=[]), TranslationResult(hypotheses=[['▁La', '▁mayoría', '▁del', '▁estado']], scores=[-2.126070976257324], attention=[], logits=[])])
# INFO:argostranslate.utils:('value_hypotheses:', [('Ministro de Hacienda, se inició un programa de estabilización. La mayoría del estado', -4.077781558036804)])
# INFO:argostranslate.utils:('translated_paragraphs:', [[('Ministro de Hacienda, se inició un programa de estabilización. La mayoría del estado', -4.077781558036804)]])
# INFO:argostranslate.utils:('hypotheses_to_return:', [('Ministro de Hacienda, se inició un programa de estabilización. La mayoría del estado', -4.077781558036804)])
# INFO:argostranslate.utils:('paragraphs:', ['companies were privatized and the fiscal and banking systems were reformed.'])
# INFO:argostranslate.utils:('apply_packaged_translation', 'companies were privatized and the fiscal and banking systems were reformed.')
# INFO:argostranslate.utils:('Splitting sentences using SBD Model: (en) StanzaSentencizer',)
# INFO:argostranslate.utils:('sentences', ['companies were privatized and the fiscal and banking systems were reformed.'])
# INFO:argostranslate.utils:('tokenized', [['▁companies', '▁were', '▁privati', 'z', 'ed', '▁and', '▁the', '▁fiscal', '▁and', '▁banking', '▁systems', '▁were', '▁reform', 'ed', '.']])
# INFO:argostranslate.utils:('translated_batches', [TranslationResult(hypotheses=[['▁empresas', '▁fueron', '▁privati', 'zada', 's', '▁y', '▁los', '▁sistemas', '▁fiscales', '▁y', '▁bancario', 's', '▁fueron', '▁reforma', 'dos', '.']], scores=[-2.9605398178100586], attention=[], logits=[])])
# INFO:argostranslate.utils:('value_hypotheses:', [('empresas fueron privatizadas y los sistemas fiscales y bancarios fueron reformados.', -2.9605398178100586)])
# INFO:argostranslate.utils:('translated_paragraphs:', [[('empresas fueron privatizadas y los sistemas fiscales y bancarios fueron reformados.', -2.9605398178100586)]])
# INFO:argostranslate.utils:('hypotheses_to_return:', [('empresas fueron privatizadas y los sistemas fiscales y bancarios fueron reformados.', -2.9605398178100586)])
# INFO:argostranslate.utils:('paragraphs:', ['The budget was balanced and public debt was reduced. A central bank along'])
# INFO:argostranslate.utils:('apply_packaged_translation', 'The budget was balanced and public debt was reduced. A central bank along')
# INFO:argostranslate.utils:('Splitting sentences using SBD Model: (en) StanzaSentencizer',)
# INFO:argostranslate.utils:('sentences', ['The budget was balanced and public debt was reduced.', 'A central bank along'])
# INFO:argostranslate.utils:('tokenized', [['▁The', '▁budget', '▁was', '▁balanced', '▁and', '▁public', '▁debt', '▁was', '▁reduced', '.'], ['▁A', '▁central', '▁bank', '▁along']])
# INFO:argostranslate.utils:('translated_batches', [TranslationResult(hypotheses=[['▁El', '▁presupuesto', '▁es', '▁equilibrado', '▁y', '▁la', '▁deuda', '▁pública', '▁se', '▁reduce', '.']], scores=[-2.5626254081726074], attention=[], logits=[]), TranslationResult(hypotheses=[['▁Un', '▁banco', '▁central']], scores=[-1.1623344421386719], attention=[], logits=[])])
# INFO:argostranslate.utils:('value_hypotheses:', [('El presupuesto es equilibrado y la deuda pública se reduce. Un banco central', -3.7249598503112793)])
# INFO:argostranslate.utils:('translated_paragraphs:', [[('El presupuesto es equilibrado y la deuda pública se reduce. Un banco central', -3.7249598503112793)]])
# INFO:argostranslate.utils:('hypotheses_to_return:', [('El presupuesto es equilibrado y la deuda pública se reduce. Un banco central', -3.7249598503112793)])
# INFO:argostranslate.utils:('paragraphs:', ['the lines of the Bank of England was founded, the Bank of Japan, as well as a'])
# INFO:argostranslate.utils:('apply_packaged_translation', 'the lines of the Bank of England was founded, the Bank of Japan, as well as a')
# INFO:argostranslate.utils:('Splitting sentences using SBD Model: (en) StanzaSentencizer',)
# INFO:argostranslate.utils:('sentences', ['the lines of the Bank of England was founded, the Bank of Japan, as well as a'])
# INFO:argostranslate.utils:('tokenized', [['▁the', '▁lines', '▁of', '▁the', '▁Bank', '▁of', '▁England', '▁was', '▁founded', ',', '▁the', '▁Bank', '▁of', '▁Japan', ',', '▁as', '▁well', '▁as', '▁a']])
# INFO:argostranslate.utils:('translated_batches', [TranslationResult(hypotheses=[['▁las', '▁líneas', '▁del', '▁Banco', '▁de', '▁Inglaterra', '▁fue', '▁fundada', ',', '▁el', '▁Banco', '▁de', '▁Japón', ',', '▁así', '▁como', '▁un']], scores=[-3.82576847076416], attention=[], logits=[])])
# INFO:argostranslate.utils:('value_hypotheses:', [('las líneas del Banco de Inglaterra fue fundada, el Banco de Japón, así como un', -3.82576847076416)])
# INFO:argostranslate.utils:('translated_paragraphs:', [[('las líneas del Banco de Inglaterra fue fundada, el Banco de Japón, así como un', -3.82576847076416)]])
# INFO:argostranslate.utils:('hypotheses_to_return:', [('las líneas del Banco de Inglaterra fue fundada, el Banco de Japón, así como un', -3.82576847076416)])
# INFO:argostranslate.utils:('paragraphs:', ['series of official specialized banks: mortgage banks, agricultural, foreign'])
# INFO:argostranslate.utils:('apply_packaged_translation', 'series of official specialized banks: mortgage banks, agricultural, foreign')
# INFO:argostranslate.utils:('Splitting sentences using SBD Model: (en) StanzaSentencizer',)
# INFO:argostranslate.utils:('sentences', ['series of official specialized banks: mortgage banks, agricultural, foreign'])
# INFO:argostranslate.utils:('tokenized', [['▁series', '▁of', '▁official', '▁specialized', '▁banks', ':', '▁mortgage', '▁banks', ',', '▁agricultural', ',', '▁foreign']])
# INFO:argostranslate.utils:('translated_batches', [TranslationResult(hypotheses=[['▁serie', '▁de', '▁bancos', '▁oficiales', '▁especializados', ':', '▁bancos', '▁hipoteca', 'rios', ',', '▁agrícolas', ',', '▁extranjeros']], scores=[-3.442115306854248], attention=[], logits=[])])
# INFO:argostranslate.utils:('value_hypotheses:', [('serie de bancos oficiales especializados: bancos hipotecarios, agrícolas, extranjeros', -3.442115306854248)])
# INFO:argostranslate.utils:('translated_paragraphs:', [[('serie de bancos oficiales especializados: bancos hipotecarios, agrícolas, extranjeros', -3.442115306854248)]])
# INFO:argostranslate.utils:('hypotheses_to_return:', [('serie de bancos oficiales especializados: bancos hipotecarios, agrícolas, extranjeros', -3.442115306854248)])
# INFO:argostranslate.utils:('paragraphs:', ['trade, industrial banks, post office savings banks, etc. Inflation was contained.'])
# INFO:argostranslate.utils:('apply_packaged_translation', 'trade, industrial banks, post office savings banks, etc. Inflation was contained.')
# INFO:argostranslate.utils:('Splitting sentences using SBD Model: (en) StanzaSentencizer',)
# INFO:argostranslate.utils:('sentences', ['trade, industrial banks, post office savings banks, etc.', 'Inflation was contained.'])
# INFO:argostranslate.utils:('tokenized', [['▁trade', ',', '▁industrial', '▁banks', ',', '▁post', '▁office', '▁savings', '▁banks', ',', '▁etc', '.'], ['▁In', 'f', 'lation', '▁was', '▁contained', '.']])
# INFO:argostranslate.utils:('translated_batches', [TranslationResult(hypotheses=[['▁comercio', ',', '▁bancos', '▁industriales', ',', '▁bancos', '▁de', '▁ahorro', '▁de', '▁oficinas', '▁postal', 'es', ',', '▁etc', '.']], scores=[-3.0983619689941406], attention=[], logits=[]), TranslationResult(hypotheses=[['▁La', '▁inflación', '▁estaba', '▁contenida', '.']], scores=[-2.273550033569336], attention=[], logits=[])])
# INFO:argostranslate.utils:('value_hypotheses:', [('comercio, bancos industriales, bancos de ahorro de oficinas postales, etc. La inflación estaba contenida.', -5.371912002563477)])
# INFO:argostranslate.utils:('translated_paragraphs:', [[('comercio, bancos industriales, bancos de ahorro de oficinas postales, etc. La inflación estaba contenida.', -5.371912002563477)]])
# INFO:argostranslate.utils:('hypotheses_to_return:', [('comercio, bancos industriales, bancos de ahorro de oficinas postales, etc. La inflación estaba contenida.', -5.371912002563477)])
# INFO:argostranslate.utils:('paragraphs:', ['A result of privatization was the formation of the so-called zaibatsu, large'])
# INFO:argostranslate.utils:('apply_packaged_translation', 'A result of privatization was the formation of the so-called zaibatsu, large')
# INFO:argostranslate.utils:('Splitting sentences using SBD Model: (en) StanzaSentencizer',)
# INFO:argostranslate.utils:('sentences', ['A result of privatization was the formation of the so-called zaibatsu, large'])
# INFO:argostranslate.utils:('tokenized', [['▁A', '▁result', '▁of', '▁privatization', '▁was', '▁the', '▁formation', '▁of', '▁the', '▁so', '-', 'called', '▁z', 'ai', 'ba', 'tsu', ',', '▁large']])
# INFO:argostranslate.utils:('translated_batches', [TranslationResult(hypotheses=[['▁A', '▁result', '▁of', '▁privatization', '▁was', '▁the', '▁formation', '▁of', '▁the', '▁so', '-', 'called', '▁z', 'ai', 'ba', 'tsu', ',', '▁large']], scores=[-2.312406063079834], attention=[], logits=[])])
# INFO:argostranslate.utils:('value_hypotheses:', [('A result of privatization was the formation of the so-called zaibatsu, large', -2.312406063079834)])
# INFO:argostranslate.utils:('translated_paragraphs:', [[('A result of privatization was the formation of the so-called zaibatsu, large', -2.312406063079834)]])
# INFO:argostranslate.utils:('hypotheses_to_return:', [('A result of privatization was the formation of the so-called zaibatsu, large', -2.312406063079834)])
# INFO:argostranslate.utils:('paragraphs:', ['family and financial-industrial conglomerates which benefited from the sale of'])
# INFO:argostranslate.utils:('apply_packaged_translation', 'family and financial-industrial conglomerates which benefited from the sale of')
# INFO:argostranslate.utils:('Splitting sentences using SBD Model: (en) StanzaSentencizer',)
# INFO:argostranslate.utils:('sentences', ['family and financial-industrial conglomerates which benefited from the sale of'])
# INFO:argostranslate.utils:('tokenized', [['▁family', '▁and', '▁financial', '-', 'in', 'dust', 'rial', '▁con', 'glo', 'mera', 'tes', '▁which', '▁benefit', 'ed', '▁from', '▁the', '▁sale', '▁of']])
# INFO:argostranslate.utils:('translated_batches', [TranslationResult(hypotheses=[['▁familia', '▁y', '▁con', 'glo', 'mer', 'ados', '▁industriales', '▁financieros', '▁que', '▁se', '▁beneficiar', 'on', '▁de', '▁la', '▁venta', '▁de']], scores=[-4.215337753295898], attention=[], logits=[])])
# INFO:argostranslate.utils:('value_hypotheses:', [('familia y conglomerados industriales financieros que se beneficiaron de la venta de', -4.215337753295898)])
# INFO:argostranslate.utils:('translated_paragraphs:', [[('familia y conglomerados industriales financieros que se beneficiaron de la venta de', -4.215337753295898)]])
# INFO:argostranslate.utils:('hypotheses_to_return:', [('familia y conglomerados industriales financieros que se beneficiaron de la venta de', -4.215337753295898)])
# INFO:argostranslate.utils:('paragraphs:', ['state companies at reduced prices (a similar thing happened in Russia with'])
# INFO:argostranslate.utils:('apply_packaged_translation', 'state companies at reduced prices (a similar thing happened in Russia with')
# INFO:argostranslate.utils:('Splitting sentences using SBD Model: (en) StanzaSentencizer',)
# INFO:argostranslate.utils:('sentences', ['state companies at reduced prices (a similar thing happened in Russia with'])
# INFO:argostranslate.utils:('tokenized', [['▁state', '▁companies', '▁at', '▁reduced', '▁prices', '▁(', 'a', '▁similar', '▁thing', '▁happened', '▁in', '▁Russia', '▁with']])
# INFO:argostranslate.utils:('translated_batches', [TranslationResult(hypotheses=[['▁empresas', '▁estatales', '▁a', '▁precios', '▁reducido', 's', '▁(', 'una', '▁cosa', '▁similar', '▁sucedió', '▁en', '▁Rusia', '▁con']], scores=[-3.4960696697235107], attention=[], logits=[])])
# INFO:argostranslate.utils:('value_hypotheses:', [('empresas estatales a precios reducidos (una cosa similar sucedió en Rusia con', -3.4960696697235107)])
# INFO:argostranslate.utils:('translated_paragraphs:', [[('empresas estatales a precios reducidos (una cosa similar sucedió en Rusia con', -3.4960696697235107)]])
# INFO:argostranslate.utils:('hypotheses_to_return:', [('empresas estatales a precios reducidos (una cosa similar sucedió en Rusia con', -3.4960696697235107)])
# INFO:argostranslate.utils:('paragraphs:', ['post-communist privatization); the best known ones were Mitsubishi, Sumi-'])
# INFO:argostranslate.utils:('apply_packaged_translation', 'post-communist privatization); the best known ones were Mitsubishi, Sumi-')
# INFO:argostranslate.utils:('Splitting sentences using SBD Model: (en) StanzaSentencizer',)
# INFO:argostranslate.utils:('sentences', ['post-communist privatization); the best known ones were Mitsubishi, Sumi-'])
# INFO:argostranslate.utils:('tokenized', [['▁post', '-', 'com', 'mun', 'ist', '▁privatization', ');', '▁the', '▁best', '▁known', '▁ones', '▁were', '▁Mi', 'tsu', 'bi', 'shi', ',', '▁Su', 'mi', '-']])
# INFO:argostranslate.utils:('translated_batches', [TranslationResult(hypotheses=[['▁privatización', '▁post', 'com', 'un', 'ista', ');', '▁las', '▁más', '▁conocida', 's', '▁fueron', '▁Mi', 'tsu', 'bi', 'shi', ',', '▁Su', 'mi', '-']], scores=[-3.729449987411499], attention=[], logits=[])])
# INFO:argostranslate.utils:('value_hypotheses:', [('privatización postcomunista); las más conocidas fueron Mitsubishi, Sumi-', -3.729449987411499)])
# INFO:argostranslate.utils:('translated_paragraphs:', [[('privatización postcomunista); las más conocidas fueron Mitsubishi, Sumi-', -3.729449987411499)]])
# INFO:argostranslate.utils:('hypotheses_to_return:', [('privatización postcomunista); las más conocidas fueron Mitsubishi, Sumi-', -3.729449987411499)])
# INFO:argostranslate.utils:('paragraphs:', ['tomo and Yasui. These zaibatsu carried great political and economic clout in'])
# INFO:argostranslate.utils:('apply_packaged_translation', 'tomo and Yasui. These zaibatsu carried great political and economic clout in')
# INFO:argostranslate.utils:('Splitting sentences using SBD Model: (en) StanzaSentencizer',)
# INFO:argostranslate.utils:('sentences', ['tomo and Yasui.', 'These zaibatsu carried great political and economic clout in'])
# INFO:argostranslate.utils:('tokenized', [['▁to', 'mo', '▁and', '▁Ya', 's', 'ui', '.'], ['▁These', '▁z', 'ai', 'ba', 'tsu', '▁carried', '▁great', '▁political', '▁and', '▁economic', '▁cl', 'out', '▁in']])
# INFO:argostranslate.utils:('translated_batches', [TranslationResult(hypotheses=[['▁To', 'mo', '▁y', '▁Ya', 's', 'ui', '.']], scores=[-0.7670605182647705], attention=[], logits=[]), TranslationResult(hypotheses=[['▁Estos', '▁z', 'ai', 'ba', 'tsu', '▁llevaba', 'n', '▁gran', '▁cl', 'out', '▁político', '▁y', '▁económico']], scores=[-4.097262382507324], attention=[], logits=[])])
# INFO:argostranslate.utils:('value_hypotheses:', [('Tomo y Yasui. Estos zaibatsu llevaban gran clout político y económico', -4.864322900772095)])
# INFO:argostranslate.utils:('translated_paragraphs:', [[('Tomo y Yasui. Estos zaibatsu llevaban gran clout político y económico', -4.864322900772095)]])
# INFO:argostranslate.utils:('hypotheses_to_return:', [('Tomo y Yasui. Estos zaibatsu llevaban gran clout político y económico', -4.864322900772095)])
# INFO:argostranslate.utils:('paragraphs:', ['Japan until they were formally dissolved after World War H, although today'])
# INFO:argostranslate.utils:('apply_packaged_translation', 'Japan until they were formally dissolved after World War H, although today')
# INFO:argostranslate.utils:('Splitting sentences using SBD Model: (en) StanzaSentencizer',)
# INFO:argostranslate.utils:('sentences', ['Japan until they were formally dissolved after World War H, although today'])
# INFO:argostranslate.utils:('tokenized', [['▁Japan', '▁until', '▁they', '▁were', '▁formally', '▁dissolve', 'd', '▁after', '▁World', '▁War', '▁H', ',', '▁although', '▁today']])
# INFO:argostranslate.utils:('translated_batches', [TranslationResult(hypotheses=[['▁Japón', '▁hasta', '▁que', '▁fueron', '▁oficialmente', '▁dis', 'uel', 'tos', '▁después', '▁de', '▁la', '▁Guerra', '▁Mundial', '▁H', ',', '▁aunque', '▁hoy']], scores=[-3.2106757164001465], attention=[], logits=[])])
# INFO:argostranslate.utils:('value_hypotheses:', [('Japón hasta que fueron oficialmente disueltos después de la Guerra Mundial H, aunque hoy', -3.2106757164001465)])
# INFO:argostranslate.utils:('translated_paragraphs:', [[('Japón hasta que fueron oficialmente disueltos después de la Guerra Mundial H, aunque hoy', -3.2106757164001465)]])
# INFO:argostranslate.utils:('hypotheses_to_return:', [('Japón hasta que fueron oficialmente disueltos después de la Guerra Mundial H, aunque hoy', -3.2106757164001465)])
# INFO:argostranslate.utils:('paragraphs:', ['some still exist with the softer name of keiretsu. (Zaibatsu has a rather sinister'])
# INFO:argostranslate.utils:('apply_packaged_translation', 'some still exist with the softer name of keiretsu. (Zaibatsu has a rather sinister')
# INFO:argostranslate.utils:('Splitting sentences using SBD Model: (en) StanzaSentencizer',)
# INFO:argostranslate.utils:('sentences', ['some still exist with the softer name of keiretsu.', '(Zaibatsu has a rather sinister'])
# INFO:argostranslate.utils:('tokenized', [['▁some', '▁still', '▁exist', '▁with', '▁the', '▁soft', 'er', '▁name', '▁of', '▁ke', 'ire', 'tsu', '.'], ['▁(', 'Z', 'ai', 'ba', 'tsu', '▁has', '▁a', '▁rather', '▁sin', 'ister']])
# INFO:argostranslate.utils:('translated_batches', [TranslationResult(hypotheses=[['▁algunos', '▁todavía', '▁existen', '▁con', '▁el', '▁nombre', '▁más', '▁suave', '▁del', '▁ke', 'ire', 'tsu', '.']], scores=[-2.654418706893921], attention=[], logits=[]), TranslationResult(hypotheses=[['▁(', 'Z', 'ai', 'ba', 'tsu', '▁tiene', '▁un', '▁poco', '▁sin', 'ies', 'tro']], scores=[-2.6447055339813232], attention=[], logits=[])])
# INFO:argostranslate.utils:('value_hypotheses:', [('algunos todavía existen con el nombre más suave del keiretsu. (Zaibatsu tiene un poco siniestro', -5.299124240875244)])
# INFO:argostranslate.utils:('translated_paragraphs:', [[('algunos todavía existen con el nombre más suave del keiretsu. (Zaibatsu tiene un poco siniestro', -5.299124240875244)]])
# INFO:argostranslate.utils:('hypotheses_to_return:', [('algunos todavía existen con el nombre más suave del keiretsu. (Zaibatsu tiene un poco siniestro', -5.299124240875244)])
# INFO:argostranslate.utils:('paragraphs:', ['connotation, while keiretsu simply means organization.)'])
# INFO:argostranslate.utils:('apply_packaged_translation', 'connotation, while keiretsu simply means organization.)')
# INFO:argostranslate.utils:('Splitting sentences using SBD Model: (en) StanzaSentencizer',)
# INFO:argostranslate.utils:('sentences', ['connotation, while keiretsu simply means organization.)'])
# INFO:argostranslate.utils:('tokenized', [['▁con', 'not', 'ation', ',', '▁while', '▁ke', 'ire', 'tsu', '▁simply', '▁means', '▁organization', '.', ')']])
# INFO:argostranslate.utils:('translated_batches', [TranslationResult(hypotheses=[['▁con', 'no', 'tación', ',', '▁mientras', '▁que', '▁ke', 'ire', 'tsu', '▁simplemente', '▁significa', '▁organización', '.', ')']], scores=[-2.5759053230285645], attention=[], logits=[])])
# INFO:argostranslate.utils:('value_hypotheses:', [('connotación, mientras que keiretsu simplemente significa organización.)', -2.5759053230285645)])
# INFO:argostranslate.utils:('translated_paragraphs:', [[('connotación, mientras que keiretsu simplemente significa organización.)', -2.5759053230285645)]])
# INFO:argostranslate.utils:('hypotheses_to_return:', [('connotación, mientras que keiretsu simplemente significa organización.)', -2.5759053230285645)])
# INFO:argostranslate.utils:('paragraphs:', [''])
# INFO:argostranslate.utils:('apply_packaged_translation', '')
# INFO:argostranslate.utils:('Splitting sentences using SBD Model: (en) StanzaSentencizer',)
# INFO:argostranslate.utils:('sentences', [])
# INFO:argostranslate.utils:('tokenized', [])
# INFO:argostranslate.utils:('translated_batches', [])
# INFO:argostranslate.utils:('value_hypotheses:', [('', 0)])
# INFO:argostranslate.utils:('translated_paragraphs:', [[('', 0)]])
# INFO:argostranslate.utils:('hypotheses_to_return:', [('', 0)])
# INFO:argostranslate.utils:('paragraphs:', ['Economic growth and industrialization resumed with these reforms, but'])
# INFO:argostranslate.utils:('apply_packaged_translation', 'Economic growth and industrialization resumed with these reforms, but')
# INFO:argostranslate.utils:('Splitting sentences using SBD Model: (en) StanzaSentencizer',)
# INFO:argostranslate.utils:('sentences', ['Economic growth and industrialization resumed with these reforms, but'])
# INFO:argostranslate.utils:('tokenized', [['▁Economic', '▁growth', '▁and', '▁industrial', 'ization', '▁resumed', '▁with', '▁these', '▁reforms', ',', '▁but']])
# INFO:argostranslate.utils:('translated_batches', [TranslationResult(hypotheses=[['▁El', '▁crecimiento', '▁económico', '▁y', '▁la', '▁industrial', 'ización', '▁se', '▁reanudar', 'on', '▁con', '▁estas', '▁reformas', ',', '▁pero']], scores=[-2.2637033462524414], attention=[], logits=[])])
# INFO:argostranslate.utils:('value_hypotheses:', [('El crecimiento económico y la industrialización se reanudaron con estas reformas, pero', -2.2637033462524414)])
# INFO:argostranslate.utils:('translated_paragraphs:', [[('El crecimiento económico y la industrialización se reanudaron con estas reformas, pero', -2.2637033462524414)]])
# INFO:argostranslate.utils:('hypotheses_to_return:', [('El crecimiento económico y la industrialización se reanudaron con estas reformas, pero', -2.2637033462524414)])
# INFO:argostranslate.utils:('paragraphs:', ['with fewer imbalances. Despite its emphasis on military power, Japanese'])
# INFO:argostranslate.utils:('apply_packaged_translation', 'with fewer imbalances. Despite its emphasis on military power, Japanese')
# INFO:argostranslate.utils:('Splitting sentences using SBD Model: (en) StanzaSentencizer',)
# INFO:argostranslate.utils:('sentences', ['with fewer imbalances.', 'Despite its emphasis on military power, Japanese'])
# INFO:argostranslate.utils:('tokenized', [['▁with', '▁fewer', '▁imbalance', 's', '.'], ['▁Despite', '▁its', '▁emphasis', '▁on', '▁military', '▁power', ',', '▁Japanese']])
# INFO:argostranslate.utils:('translated_batches', [TranslationResult(hypotheses=[['▁con', '▁menos', '▁desequilibrio', 's', '.']], scores=[-0.8386437296867371], attention=[], logits=[]), TranslationResult(hypotheses=[['▁A', '▁pesar', '▁de', '▁su', '▁énfasis', '▁en', '▁el', '▁poder', '▁militar', ',', '▁japonés']], scores=[-2.1198339462280273], attention=[], logits=[])])
# INFO:argostranslate.utils:('value_hypotheses:', [('con menos desequilibrios. A pesar de su énfasis en el poder militar, japonés', -2.9584776759147644)])
# INFO:argostranslate.utils:('translated_paragraphs:', [[('con menos desequilibrios. A pesar de su énfasis en el poder militar, japonés', -2.9584776759147644)]])
# INFO:argostranslate.utils:('hypotheses_to_return:', [('con menos desequilibrios. A pesar de su énfasis en el poder militar, japonés', -2.9584776759147644)])
# INFO:argostranslate.utils:('paragraphs:', ['development had orthodox characteristics: agriculture and consumer goods'])
# INFO:argostranslate.utils:('apply_packaged_translation', 'development had orthodox characteristics: agriculture and consumer goods')
# INFO:argostranslate.utils:('Splitting sentences using SBD Model: (en) StanzaSentencizer',)
# INFO:argostranslate.utils:('sentences', ['development had orthodox characteristics: agriculture and consumer goods'])
# INFO:argostranslate.utils:('tokenized', [['▁development', '▁had', '▁or', 'th', 'o', 'do', 'x', '▁characteristics', ':', '▁agriculture', '▁and', '▁consumer', '▁goods']])
# INFO:argostranslate.utils:('translated_batches', [TranslationResult(hypotheses=[['▁el', '▁desarrollo', '▁tenía', '▁características', '▁or', 'todo', 'xa', 's', ':', '▁agricultura', '▁y', '▁bienes', '▁de', '▁consumo']], scores=[-2.4600958824157715], attention=[], logits=[])])
# INFO:argostranslate.utils:('value_hypotheses:', [('el desarrollo tenía características ortodoxas: agricultura y bienes de consumo', -2.4600958824157715)])
# INFO:argostranslate.utils:('translated_paragraphs:', [[('el desarrollo tenía características ortodoxas: agricultura y bienes de consumo', -2.4600958824157715)]])
# INFO:argostranslate.utils:('hypotheses_to_return:', [('el desarrollo tenía características ortodoxas: agricultura y bienes de consumo', -2.4600958824157715)])
# INFO:argostranslate.utils:('paragraphs:', ['industries developed first. Agriculture soon suffered from a lack of land (the'])
# INFO:argostranslate.utils:('apply_packaged_translation', 'industries developed first. Agriculture soon suffered from a lack of land (the')
# INFO:argostranslate.utils:('Splitting sentences using SBD Model: (en) StanzaSentencizer',)
# INFO:argostranslate.utils:('sentences', ['industries developed first.', 'Agriculture soon suffered from a lack of land (the'])
# INFO:argostranslate.utils:('tokenized', [['▁industries', '▁developed', '▁first', '.'], ['▁Agriculture', '▁soon', '▁suffered', '▁from', '▁a', '▁lack', '▁of', '▁land', '▁(', 'the']])
# INFO:argostranslate.utils:('translated_batches', [TranslationResult(hypotheses=[['▁las', '▁industria', 's', '▁desarrollada', 's', '▁primero', '.']], scores=[-2.272108554840088], attention=[], logits=[]), TranslationResult(hypotheses=[['▁La', '▁agricultura', '▁sufrió', '▁pronto', '▁una', '▁falta', '▁de', '▁tierra', '▁(', 'la']], scores=[-4.136451244354248], attention=[], logits=[])])
# INFO:argostranslate.utils:('value_hypotheses:', [('las industrias desarrolladas primero. La agricultura sufrió pronto una falta de tierra (la', -6.408559799194336)])
# INFO:argostranslate.utils:('translated_paragraphs:', [[('las industrias desarrolladas primero. La agricultura sufrió pronto una falta de tierra (la', -6.408559799194336)]])
# INFO:argostranslate.utils:('hypotheses_to_return:', [('las industrias desarrolladas primero. La agricultura sufrió pronto una falta de tierra (la', -6.408559799194336)])
# INFO:argostranslate.utils:('paragraphs:', ['population grew much more than in the Tokugawa era) and used intensive'])
# INFO:argostranslate.utils:('apply_packaged_translation', 'population grew much more than in the Tokugawa era) and used intensive')
# INFO:argostranslate.utils:('Splitting sentences using SBD Model: (en) StanzaSentencizer',)
# INFO:argostranslate.utils:('sentences', ['population grew much more than in the Tokugawa era) and used intensive'])
# INFO:argostranslate.utils:('tokenized', [['▁population', '▁grew', '▁much', '▁more', '▁than', '▁in', '▁the', '▁To', 'ku', 'ga', 'wa', '▁era', ')', '▁and', '▁used', '▁intensive']])
# INFO:argostranslate.utils:('translated_batches', [TranslationResult(hypotheses=[['▁la', '▁población', '▁creció', '▁mucho', '▁más', '▁que', '▁en', '▁la', '▁era', '▁de', '▁To', 'ku', 'ga', 'wa', ')', '▁y', '▁us', 'ó', '▁intensivo']], scores=[-4.529836654663086], attention=[], logits=[])])
# INFO:argostranslate.utils:('value_hypotheses:', [('la población creció mucho más que en la era de Tokugawa) y usó intensivo', -4.529836654663086)])
# INFO:argostranslate.utils:('translated_paragraphs:', [[('la población creció mucho más que en la era de Tokugawa) y usó intensivo', -4.529836654663086)]])
# INFO:argostranslate.utils:('hypotheses_to_return:', [('la población creció mucho más que en la era de Tokugawa) y usó intensivo', -4.529836654663086)])
# INFO:argostranslate.utils:('paragraphs:', ['methods: selection of seeds and massive use of fertilizers. Fishing, a tradi-'])
# INFO:argostranslate.utils:('apply_packaged_translation', 'methods: selection of seeds and massive use of fertilizers. Fishing, a tradi-')
# INFO:argostranslate.utils:('Splitting sentences using SBD Model: (en) StanzaSentencizer',)
# INFO:argostranslate.utils:('sentences', ['methods: selection of seeds and massive use of fertilizers.', 'Fishing, a tradi-'])
# INFO:argostranslate.utils:('tokenized', [['▁methods', ':', '▁selection', '▁of', '▁seeds', '▁and', '▁massive', '▁use', '▁of', '▁fer', 'til', 'izer', 's', '.'], ['▁Fishing', ',', '▁a', '▁tra', 'di', '-']])
# INFO:argostranslate.utils:('translated_batches', [TranslationResult(hypotheses=[['▁métodos', ':', '▁selección', '▁de', '▁semillas', '▁y', '▁uso', '▁masivo', '▁de', '▁fer', 'til', 'izante', 's', '.']], scores=[-1.4697471857070923], attention=[], logits=[]), TranslationResult(hypotheses=[['▁Pesca', ',', '▁un', '▁tra', 'di', '-']], scores=[-2.326796293258667], attention=[], logits=[])])
# INFO:argostranslate.utils:('value_hypotheses:', [('métodos: selección de semillas y uso masivo de fertilizantes. Pesca, un tradi-', -3.7965434789657593)])
# INFO:argostranslate.utils:('translated_paragraphs:', [[('métodos: selección de semillas y uso masivo de fertilizantes. Pesca, un tradi-', -3.7965434789657593)]])
# INFO:argostranslate.utils:('hypotheses_to_return:', [('métodos: selección de semillas y uso masivo de fertilizantes. Pesca, un tradi-', -3.7965434789657593)])
# INFO:argostranslate.utils:('paragraphs:', ['tional source of food, although it did not become modernized until well into'])
# INFO:argostranslate.utils:('apply_packaged_translation', 'tional source of food, although it did not become modernized until well into')
# INFO:argostranslate.utils:('Splitting sentences using SBD Model: (en) StanzaSentencizer',)
# INFO:argostranslate.utils:('sentences', ['tional source of food, although it did not become modernized until well into'])
# INFO:argostranslate.utils:('tokenized', [['▁', 'tional', '▁source', '▁of', '▁food', ',', '▁although', '▁it', '▁did', '▁not', '▁become', '▁modern', 'ized', '▁until', '▁well', '▁into']])
# INFO:argostranslate.utils:('translated_batches', [TranslationResult(hypotheses=[['▁fuente', '▁de', '▁alimento', ',', '▁aunque', '▁no', '▁se', '▁modern', 'izó', '▁hasta', '▁bien', '▁entrado']], scores=[-4.775765895843506], attention=[], logits=[])])
# INFO:argostranslate.utils:('value_hypotheses:', [('fuente de alimento, aunque no se modernizó hasta bien entrado', -4.775765895843506)])
# INFO:argostranslate.utils:('translated_paragraphs:', [[('fuente de alimento, aunque no se modernizó hasta bien entrado', -4.775765895843506)]])
# INFO:argostranslate.utils:('hypotheses_to_return:', [('fuente de alimento, aunque no se modernizó hasta bien entrado', -4.775765895843506)])
# INFO:argostranslate.utils:('paragraphs:', ['the twentieth century, increased its catches at a faster rate than agricultural'])
# INFO:argostranslate.utils:('apply_packaged_translation', 'the twentieth century, increased its catches at a faster rate than agricultural')
# INFO:argostranslate.utils:('Splitting sentences using SBD Model: (en) StanzaSentencizer',)
# INFO:argostranslate.utils:('sentences', ['the twentieth century, increased its catches at a faster rate than agricultural'])
# INFO:argostranslate.utils:('tokenized', [['▁the', '▁twentieth', '▁century', ',', '▁increased', '▁its', '▁catch', 'es', '▁at', '▁a', '▁faster', '▁rate', '▁than', '▁agricultural']])
# INFO:argostranslate.utils:('translated_batches', [TranslationResult(hypotheses=[['▁el', '▁siglo', '▁XX', ',', '▁aumentó', '▁sus', '▁captura', 's', '▁a', '▁un', '▁ritmo', '▁más', '▁rápido', '▁que', '▁la', '▁agricultura']], scores=[-3.270901918411255], attention=[], logits=[])])
# INFO:argostranslate.utils:('value_hypotheses:', [('el siglo XX, aumentó sus capturas a un ritmo más rápido que la agricultura', -3.270901918411255)])
# INFO:argostranslate.utils:('translated_paragraphs:', [[('el siglo XX, aumentó sus capturas a un ritmo más rápido que la agricultura', -3.270901918411255)]])
# INFO:argostranslate.utils:('hypotheses_to_return:', [('el siglo XX, aumentó sus capturas a un ritmo más rápido que la agricultura', -3.270901918411255)])
# INFO:argostranslate.utils:('paragraphs:', ['production. The textile industry also developed rapidly: the silk industry'])
# INFO:argostranslate.utils:('apply_packaged_translation', 'production. The textile industry also developed rapidly: the silk industry')
# INFO:argostranslate.utils:('Splitting sentences using SBD Model: (en) StanzaSentencizer',)
# INFO:argostranslate.utils:('sentences', ['production.', 'The textile industry also developed rapidly: the silk industry'])
# INFO:argostranslate.utils:('tokenized', [['▁production', '.'], ['▁The', '▁text', 'ile', '▁industry', '▁also', '▁developed', '▁rapidly', ':', '▁the', '▁silk', '▁industry']])
# INFO:argostranslate.utils:('translated_batches', [TranslationResult(hypotheses=[['▁producción', '.']], scores=[-0.5282253623008728], attention=[], logits=[]), TranslationResult(hypotheses=[['▁La', '▁industria', '▁text', 'il', '▁también', '▁se', '▁desarrolló', '▁rápidamente', ':', '▁la', '▁industria', '▁de', '▁la', '▁se', 'da']], scores=[-1.9458624124526978], attention=[], logits=[])])
# INFO:argostranslate.utils:('value_hypotheses:', [('producción. La industria textil también se desarrolló rápidamente: la industria de la seda', -2.4740877747535706)])
# INFO:argostranslate.utils:('translated_paragraphs:', [[('producción. La industria textil también se desarrolló rápidamente: la industria de la seda', -2.4740877747535706)]])
# INFO:argostranslate.utils:('hypotheses_to_return:', [('producción. La industria textil también se desarrolló rápidamente: la industria de la seda', -2.4740877747535706)])
# INFO:argostranslate.utils:('paragraphs:', ['modernized and started to export finished products instead of just raw silk.'])
# INFO:argostranslate.utils:('apply_packaged_translation', 'modernized and started to export finished products instead of just raw silk.')
# INFO:argostranslate.utils:('Splitting sentences using SBD Model: (en) StanzaSentencizer',)
# INFO:argostranslate.utils:('sentences', ['modernized and started to export finished products instead of just raw silk.'])
# INFO:argostranslate.utils:('tokenized', [['▁modern', 'ized', '▁and', '▁started', '▁to', '▁export', '▁finished', '▁products', '▁instead', '▁of', '▁just', '▁raw', '▁silk', '.']])
# INFO:argostranslate.utils:('translated_batches', [TranslationResult(hypotheses=[['▁modern', 'izado', '▁y', '▁comenzó', '▁a', '▁export', 'ar', '▁productos', '▁acabado', 's', '▁en', '▁lugar', '▁de', '▁se', 'da', '▁cru', 'da', '.']], scores=[-3.989034652709961], attention=[], logits=[])])
# INFO:argostranslate.utils:('value_hypotheses:', [('modernizado y comenzó a exportar productos acabados en lugar de seda cruda.', -3.989034652709961)])
# INFO:argostranslate.utils:('translated_paragraphs:', [[('modernizado y comenzó a exportar productos acabados en lugar de seda cruda.', -3.989034652709961)]])
# INFO:argostranslate.utils:('hypotheses_to_return:', [('modernizado y comenzó a exportar productos acabados en lugar de seda cruda.', -3.989034652709961)])
# INFO:argostranslate.utils:('paragraphs:', ['The cotton industry, supplied with Indian raw material, soon was the biggest'])
# INFO:argostranslate.utils:('apply_packaged_translation', 'The cotton industry, supplied with Indian raw material, soon was the biggest')
# INFO:argostranslate.utils:('Splitting sentences using SBD Model: (en) StanzaSentencizer',)
# INFO:argostranslate.utils:('sentences', ['The cotton industry, supplied with Indian raw material, soon was the biggest'])
# INFO:argostranslate.utils:('tokenized', [['▁The', '▁cotton', '▁industry', ',', '▁supplied', '▁with', '▁Indian', '▁raw', '▁material', ',', '▁soon', '▁was', '▁the', '▁biggest']])
# INFO:argostranslate.utils:('translated_batches', [TranslationResult(hypotheses=[['▁La', '▁industria', '▁del', '▁algodón', ',', '▁suministra', 'da', '▁con', '▁materia', '▁prima', '▁in', 'dia', ',', '▁pronto', '▁fue', '▁la', '▁mayor']], scores=[-3.0692811012268066], attention=[], logits=[])])
# INFO:argostranslate.utils:('value_hypotheses:', [('La industria del algodón, suministrada con materia prima india, pronto fue la mayor', -3.0692811012268066)])
# INFO:argostranslate.utils:('translated_paragraphs:', [[('La industria del algodón, suministrada con materia prima india, pronto fue la mayor', -3.0692811012268066)]])
# INFO:argostranslate.utils:('hypotheses_to_return:', [('La industria del algodón, suministrada con materia prima india, pronto fue la mayor', -3.0692811012268066)])
# INFO:argostranslate.utils:('paragraphs:', ['exporter.'])
# INFO:argostranslate.utils:('apply_packaged_translation', 'exporter.')
# INFO:argostranslate.utils:('Splitting sentences using SBD Model: (en) StanzaSentencizer',)
# INFO:argostranslate.utils:('sentences', ['exporter.'])
# INFO:argostranslate.utils:('tokenized', [['▁export', 'er', '.']])
# INFO:argostranslate.utils:('translated_batches', [TranslationResult(hypotheses=[['▁export', 'ador', '.']], scores=[-0.3907793462276459], attention=[], logits=[])])
# INFO:argostranslate.utils:('value_hypotheses:', [('exportador.', -0.3907793462276459)])
# INFO:argostranslate.utils:('translated_paragraphs:', [[('exportador.', -0.3907793462276459)]])
# INFO:argostranslate.utils:('hypotheses_to_return:', [('exportador.', -0.3907793462276459)])
# INFO:argostranslate.utils:('paragraphs:', [''])
# INFO:argostranslate.utils:('apply_packaged_translation', '')
# INFO:argostranslate.utils:('Splitting sentences using SBD Model: (en) StanzaSentencizer',)
# INFO:argostranslate.utils:('sentences', [])
# INFO:argostranslate.utils:('tokenized', [])
# INFO:argostranslate.utils:('translated_batches', [])
# INFO:argostranslate.utils:('value_hypotheses:', [('', 0)])
# INFO:argostranslate.utils:('translated_paragraphs:', [[('', 0)]])
# INFO:argostranslate.utils:('hypotheses_to_return:', [('', 0)])
# INFO:argostranslate.utils:('paragraphs:', ['Just before World War I Japan was already a great industrial, political, and'])
# INFO:argostranslate.utils:('apply_packaged_translation', 'Just before World War I Japan was already a great industrial, political, and')
# INFO:argostranslate.utils:('Splitting sentences using SBD Model: (en) StanzaSentencizer',)
# INFO:argostranslate.utils:('sentences', ['Just before World War I Japan was already a great industrial, political, and'])
# INFO:argostranslate.utils:('tokenized', [['▁Just', '▁before', '▁World', '▁War', '▁I', '▁Japan', '▁was', '▁already', '▁a', '▁great', '▁industrial', ',', '▁political', ',', '▁and']])
# INFO:argostranslate.utils:('translated_batches', [TranslationResult(hypotheses=[['▁Justo', '▁antes', '▁de', '▁la', '▁Primera', '▁Guerra', '▁Mundial', '▁Japón', '▁ya', '▁era', '▁un', '▁gran', '▁industrial', ',', '▁político', '▁y']], scores=[-2.199880838394165], attention=[], logits=[])])
# INFO:argostranslate.utils:('value_hypotheses:', [('Justo antes de la Primera Guerra Mundial Japón ya era un gran industrial, político y', -2.199880838394165)])
# INFO:argostranslate.utils:('translated_paragraphs:', [[('Justo antes de la Primera Guerra Mundial Japón ya era un gran industrial, político y', -2.199880838394165)]])
# INFO:argostranslate.utils:('hypotheses_to_return:', [('Justo antes de la Primera Guerra Mundial Japón ya era un gran industrial, político y', -2.199880838394165)])
# INFO:argostranslate.utils:('paragraphs:', ['military power in Asia. It had defeated China in 1895 and Russia in 1905 in'])
# INFO:argostranslate.utils:('apply_packaged_translation', 'military power in Asia. It had defeated China in 1895 and Russia in 1905 in')
# INFO:argostranslate.utils:('Splitting sentences using SBD Model: (en) StanzaSentencizer',)
# INFO:argostranslate.utils:('sentences', ['military power in Asia.', 'It had defeated China in 1895 and Russia in 1905 in'])
# INFO:argostranslate.utils:('tokenized', [['▁military', '▁power', '▁in', '▁Asia', '.'], ['▁It', '▁had', '▁defeat', 'ed', '▁China', '▁in', '▁18', '95', '▁and', '▁Russia', '▁in', '▁19', '05', '▁in']])
# INFO:argostranslate.utils:('translated_batches', [TranslationResult(hypotheses=[['▁poder', '▁militar', '▁en', '▁Asia', '.']], scores=[-1.9506906270980835], attention=[], logits=[]), TranslationResult(hypotheses=[['▁Había', '▁derrota', 'do', '▁a', '▁China', '▁en', '▁18', '95', '▁y', '▁Rusia', '▁en', '▁19', '05', '▁en']], scores=[-1.2570911645889282], attention=[], logits=[])])
# INFO:argostranslate.utils:('value_hypotheses:', [('poder militar en Asia. Había derrotado a China en 1895 y Rusia en 1905 en', -3.2077817916870117)])
# INFO:argostranslate.utils:('translated_paragraphs:', [[('poder militar en Asia. Había derrotado a China en 1895 y Rusia en 1905 en', -3.2077817916870117)]])
# INFO:argostranslate.utils:('hypotheses_to_return:', [('poder militar en Asia. Había derrotado a China en 1895 y Rusia en 1905 en', -3.2077817916870117)])
# INFO:argostranslate.utils:('paragraphs:', ['wars that had opened the door to its imperialist expansion. Although its'])
# INFO:argostranslate.utils:('apply_packaged_translation', 'wars that had opened the door to its imperialist expansion. Although its')
# INFO:argostranslate.utils:('Splitting sentences using SBD Model: (en) StanzaSentencizer',)
# INFO:argostranslate.utils:('sentences', ['wars that had opened the door to its imperialist expansion.', 'Although its'])
# INFO:argostranslate.utils:('tokenized', [['▁war', 's', '▁that', '▁had', '▁opened', '▁the', '▁door', '▁to', '▁its', '▁imperialist', '▁expansion', '.'], ['▁Although', '▁its']])
# INFO:argostranslate.utils:('translated_batches', [TranslationResult(hypotheses=[['▁guerra', 's', '▁que', '▁habían', '▁abierto', '▁la', '▁puerta', '▁a', '▁su', '▁expansión', '▁imperialista', '.']], scores=[-1.6125978231430054], attention=[], logits=[]), TranslationResult(hypotheses=[['▁Aunque', '▁es']], scores=[-2.831059217453003], attention=[], logits=[])])
# INFO:argostranslate.utils:('value_hypotheses:', [('guerras que habían abierto la puerta a su expansión imperialista. Aunque es', -4.443657040596008)])
# INFO:argostranslate.utils:('translated_paragraphs:', [[('guerras que habían abierto la puerta a su expansión imperialista. Aunque es', -4.443657040596008)]])
# INFO:argostranslate.utils:('hypotheses_to_return:', [('guerras que habían abierto la puerta a su expansión imperialista. Aunque es', -4.443657040596008)])
# ...
# INFO:argostranslate.utils:('Splitting sentences using SBD Model: (en) StanzaSentencizer',)
# INFO:argostranslate.utils:('sentences', ['stressed tensions in almost all of the economically advanced nations and, in a'])
# INFO:argostranslate.utils:('tokenized', [['▁stressed', '▁tension', 's', '▁in', '▁almost', '▁all', '▁of', '▁the', '▁economically', '▁advanced', '▁nations', '▁and', ',', '▁in', '▁a']])
# INFO:argostranslate.utils:('translated_batches', [TranslationResult(hypotheses=[['▁acentu', 'ó', '▁las', '▁tensiones', '▁en', '▁casi', '▁todas', '▁las', '▁naciones', '▁económica', 'mente', '▁avanzada', 's', '▁y', ',', '▁en']], scores=[-3.823758840560913], attention=[], logits=[])])
# INFO:argostranslate.utils:('value_hypotheses:', [('acentuó las tensiones en casi todas las naciones económicamente avanzadas y, en', -3.823758840560913)])
# INFO:argostranslate.utils:('translated_paragraphs:', [[('acentuó las tensiones en casi todas las naciones económicamente avanzadas y, en', -3.823758840560913)]])
# INFO:argostranslate.utils:('hypotheses_to_return:', [('acentuó las tensiones en casi todas las naciones económicamente avanzadas y, en', -3.823758840560913)])
# INFO:argostranslate.utils:('paragraphs:', ['similar manner, it aggravated international tensions as well, particularly when'])
# INFO:argostranslate.utils:('apply_packaged_translation', 'similar manner, it aggravated international tensions as well, particularly when')
# INFO:argostranslate.utils:('Splitting sentences using SBD Model: (en) StanzaSentencizer',)
# INFO:argostranslate.utils:('sentences', ['similar manner, it aggravated international tensions as well, particularly when'])
# INFO:argostranslate.utils:('tokenized', [['▁similar', '▁manner', ',', '▁it', '▁a', 'g', 'grav', 'ated', '▁international', '▁tension', 's', '▁as', '▁well', ',', '▁particularly', '▁when']])
# INFO:argostranslate.utils:('translated_batches', [TranslationResult(hypotheses=[['▁de', '▁manera', '▁similar', ',', '▁también', '▁agrava', '▁las', '▁tensiones', '▁internacionales', ',', '▁en', '▁particular', '▁cuando']], scores=[-4.357725143432617], attention=[], logits=[])])
# INFO:argostranslate.utils:('value_hypotheses:', [('de manera similar, también agrava las tensiones internacionales, en particular cuando', -4.357725143432617)])
# INFO:argostranslate.utils:('translated_paragraphs:', [[('de manera similar, también agrava las tensiones internacionales, en particular cuando', -4.357725143432617)]])
# INFO:argostranslate.utils:('hypotheses_to_return:', [('de manera similar, también agrava las tensiones internacionales, en particular cuando', -4.357725143432617)])
# INFO:argostranslate.utils:('paragraphs:', ['the politicians in those countries tried to solve the tensions via protectionism,'])
# INFO:argostranslate.utils:('apply_packaged_translation', 'the politicians in those countries tried to solve the tensions via protectionism,')
# INFO:argostranslate.utils:('Splitting sentences using SBD Model: (en) StanzaSentencizer',)
# INFO:argostranslate.utils:('sentences', ['the politicians in those countries tried to solve the tensions via protectionism,'])
# INFO:argostranslate.utils:('tokenized', [['▁the', '▁politicians', '▁in', '▁those', '▁countries', '▁tried', '▁to', '▁solve', '▁the', '▁tension', 's', '▁via', '▁protection', 'ism', ',']])
# INFO:argostranslate.utils:('translated_batches', [TranslationResult(hypotheses=[['▁los', '▁políticos', '▁de', '▁esos', '▁países', '▁trata', 'ron', '▁de', '▁resolver', '▁las', '▁tensiones', '▁a', '▁través', '▁del', '▁prote', 'ccion', 'ismo', ',']], scores=[-3.3992223739624023], attention=[], logits=[])])
# INFO:argostranslate.utils:('value_hypotheses:', [('los políticos de esos países trataron de resolver las tensiones a través del proteccionismo,', -3.3992223739624023)])
# INFO:argostranslate.utils:('translated_paragraphs:', [[('los políticos de esos países trataron de resolver las tensiones a través del proteccionismo,', -3.3992223739624023)]])
# INFO:argostranslate.utils:('hypotheses_to_return:', [('los políticos de esos países trataron de resolver las tensiones a través del proteccionismo,', -3.3992223739624023)])
# INFO:argostranslate.utils:('paragraphs:', ['nationalism, and imperialism. The international situation reached such a state'])
# INFO:argostranslate.utils:('apply_packaged_translation', 'nationalism, and imperialism. The international situation reached such a state')
# INFO:argostranslate.utils:('Splitting sentences using SBD Model: (en) StanzaSentencizer',)
# INFO:argostranslate.utils:('sentences', ['nationalism, and imperialism.', 'The international situation reached such a state'])
# INFO:argostranslate.utils:('tokenized', [['▁national', 'ism', ',', '▁and', '▁imperialism', '.'], ['▁The', '▁international', '▁situation', '▁reached', '▁such', '▁a', '▁state']])
# INFO:argostranslate.utils:('translated_batches', [TranslationResult(hypotheses=[['▁nacional', 'ismo', '▁y', '▁imperialismo', '.']], scores=[-1.3676137924194336], attention=[], logits=[]), TranslationResult(hypotheses=[['▁La', '▁situación', '▁internacional', '▁alcanzó', '▁ese', '▁estado']], scores=[-2.5021262168884277], attention=[], logits=[])])
# INFO:argostranslate.utils:('value_hypotheses:', [('nacionalismo y imperialismo. La situación internacional alcanzó ese estado', -3.8697400093078613)])
# INFO:argostranslate.utils:('translated_paragraphs:', [[('nacionalismo y imperialismo. La situación internacional alcanzó ese estado', -3.8697400093078613)]])
# INFO:argostranslate.utils:('hypotheses_to_return:', [('nacionalismo y imperialismo. La situación internacional alcanzó ese estado', -3.8697400093078613)])
# INFO:argostranslate.utils:('paragraphs:', ['of violence that any incident could be the spark that would ignite an explo-'])
# INFO:argostranslate.utils:('apply_packaged_translation', 'of violence that any incident could be the spark that would ignite an explo-')
# INFO:argostranslate.utils:('Splitting sentences using SBD Model: (en) StanzaSentencizer',)
# INFO:argostranslate.utils:('sentences', ['of violence that any incident could be the spark that would ignite an explo-'])
# INFO:argostranslate.utils:('tokenized', [['▁of', '▁violence', '▁that', '▁any', '▁incident', '▁could', '▁be', '▁the', '▁spark', '▁that', '▁would', '▁', 'ign', 'ite', '▁an', '▁exp', 'lo', '-']])
# INFO:argostranslate.utils:('translated_batches', [TranslationResult(hypotheses=[['▁de', '▁violencia', '▁que', '▁cualquier', '▁incidente', '▁podría', '▁ser', '▁la', '▁chi', 's', 'pa', '▁que', '▁encender', 'ía', '▁una', '▁explosión']], scores=[-4.446624279022217], attention=[], logits=[])])
# INFO:argostranslate.utils:('value_hypotheses:', [('de violencia que cualquier incidente podría ser la chispa que encendería una explosión', -4.446624279022217)])
# INFO:argostranslate.utils:('translated_paragraphs:', [[('de violencia que cualquier incidente podría ser la chispa que encendería una explosión', -4.446624279022217)]])
# INFO:argostranslate.utils:('hypotheses_to_return:', [('de violencia que cualquier incidente podría ser la chispa que encendería una explosión', -4.446624279022217)])
# INFO:argostranslate.utils:('paragraphs:', ['sion. The spark came in the Balkans in the summer of 1914, but it could just'])
# INFO:argostranslate.utils:('apply_packaged_translation', 'sion. The spark came in the Balkans in the summer of 1914, but it could just')
# INFO:argostranslate.utils:('Splitting sentences using SBD Model: (en) StanzaSentencizer',)
# INFO:argostranslate.utils:('sentences', ['sion.', 'The spark came in the Balkans in the summer of 1914, but it could just'])
# INFO:argostranslate.utils:('tokenized', [['▁si', 'on', '.'], ['▁The', '▁spark', '▁came', '▁in', '▁the', '▁Balkan', 's', '▁in', '▁the', '▁summer', '▁of', '▁19', '14', ',', '▁but', '▁it', '▁could', '▁just']])
# INFO:argostranslate.utils:('translated_batches', [TranslationResult(hypotheses=[['▁Si', 'on', '.']], scores=[-1.4312587976455688], attention=[], logits=[]), TranslationResult(hypotheses=[['▁La', '▁chi', 's', 'pa', '▁vino', '▁en', '▁los', '▁Bal', 'can', 'es', '▁en', '▁el', '▁verano', '▁de', '▁19', '14', ',', '▁pero', '▁sólo', '▁podía']], scores=[-3.638112783432007], attention=[], logits=[])])
# INFO:argostranslate.utils:('value_hypotheses:', [('Sion. La chispa vino en los Balcanes en el verano de 1914, pero sólo podía', -5.069371581077576)])
# INFO:argostranslate.utils:('translated_paragraphs:', [[('Sion. La chispa vino en los Balcanes en el verano de 1914, pero sólo podía', -5.069371581077576)]])
# INFO:argostranslate.utils:('hypotheses_to_return:', [('Sion. La chispa vino en los Balcanes en el verano de 1914, pero sólo podía', -5.069371581077576)])
# INFO:argostranslate.utils:('paragraphs:', ['as well have happened earlier or later, in the Balkans, in the Rhine valley, in'])
# INFO:argostranslate.utils:('apply_packaged_translation', 'as well have happened earlier or later, in the Balkans, in the Rhine valley, in')
# INFO:argostranslate.utils:('Splitting sentences using SBD Model: (en) StanzaSentencizer',)
# INFO:argostranslate.utils:('sentences', ['as well have happened earlier or later, in the Balkans, in the Rhine valley, in'])
# INFO:argostranslate.utils:('tokenized', [['▁as', '▁well', '▁have', '▁happened', '▁earlier', '▁or', '▁later', ',', '▁in', '▁the', '▁Balkan', 's', ',', '▁in', '▁the', '▁Rh', 'ine', '▁valley', ',', '▁in']])
# INFO:argostranslate.utils:('translated_batches', [TranslationResult(hypotheses=[['▁también', '▁han', '▁ocurrido', '▁antes', '▁o', '▁después', ',', '▁en', '▁los', '▁Bal', 'can', 'es', ',', '▁en', '▁el', '▁valle', '▁del', '▁Ri', 'n', ',', '▁en']], scores=[-3.8578126430511475], attention=[], logits=[])])
# INFO:argostranslate.utils:('value_hypotheses:', [('también han ocurrido antes o después, en los Balcanes, en el valle del Rin, en', -3.8578126430511475)])
# INFO:argostranslate.utils:('translated_paragraphs:', [[('también han ocurrido antes o después, en los Balcanes, en el valle del Rin, en', -3.8578126430511475)]])
# INFO:argostranslate.utils:('hypotheses_to_return:', [('también han ocurrido antes o después, en los Balcanes, en el valle del Rin, en', -3.8578126430511475)])
# INFO:argostranslate.utils:('paragraphs:', ['Morocco, or on the high seas. The errors caused by the social tensions were'])
# INFO:argostranslate.utils:('apply_packaged_translation', 'Morocco, or on the high seas. The errors caused by the social tensions were')
# INFO:argostranslate.utils:('Splitting sentences using SBD Model: (en) StanzaSentencizer',)
# INFO:argostranslate.utils:('sentences', ['Morocco, or on the high seas.', 'The errors caused by the social tensions were'])
# INFO:argostranslate.utils:('tokenized', [['▁Morocco', ',', '▁or', '▁on', '▁the', '▁high', '▁seas', '.'], ['▁The', '▁error', 's', '▁caused', '▁by', '▁the', '▁social', '▁tension', 's', '▁were']])
# INFO:argostranslate.utils:('translated_batches', [TranslationResult(hypotheses=[['▁Marruecos', ',', '▁o', '▁en', '▁alta', '▁mar', '.']], scores=[-0.9929606318473816], attention=[], logits=[]), TranslationResult(hypotheses=[['▁Los', '▁errores', '▁causado', 's', '▁por', '▁las', '▁tensiones', '▁sociales', '▁fueron']], scores=[-1.7373614311218262], attention=[], logits=[])])
# INFO:argostranslate.utils:('value_hypotheses:', [('Marruecos, o en alta mar. Los errores causados por las tensiones sociales fueron', -2.7303220629692078)])
# INFO:argostranslate.utils:('translated_paragraphs:', [[('Marruecos, o en alta mar. Los errores causados por las tensiones sociales fueron', -2.7303220629692078)]])
# INFO:argostranslate.utils:('hypotheses_to_return:', [('Marruecos, o en alta mar. Los errores causados por las tensiones sociales fueron', -2.7303220629692078)])
# INFO:argostranslate.utils:('paragraphs:', ['many and one of them was bound to have dramatic consequences. The world'])
# INFO:argostranslate.utils:('apply_packaged_translation', 'many and one of them was bound to have dramatic consequences. The world')
# INFO:argostranslate.utils:('Splitting sentences using SBD Model: (en) StanzaSentencizer',)
# INFO:argostranslate.utils:('sentences', ['many and one of them was bound to have dramatic consequences.', 'The world'])
# INFO:argostranslate.utils:('tokenized', [['▁many', '▁and', '▁one', '▁of', '▁them', '▁was', '▁bound', '▁to', '▁have', '▁dramatic', '▁consequences', '.'], ['▁The', '▁world']])
# INFO:argostranslate.utils:('translated_batches', [TranslationResult(hypotheses=[['▁muchos', '▁y', '▁uno', '▁de', '▁ellos', '▁estaba', '▁obligado', '▁a', '▁tener', '▁consecuencias', '▁dramática', 's', '.']], scores=[-2.494915723800659], attention=[], logits=[]), TranslationResult(hypotheses=[['▁El', '▁mundo']], scores=[-0.32324904203414917], attention=[], logits=[])])
# INFO:argostranslate.utils:('value_hypotheses:', [('muchos y uno de ellos estaba obligado a tener consecuencias dramáticas. El mundo', -2.8181647658348083)])
# INFO:argostranslate.utils:('translated_paragraphs:', [[('muchos y uno de ellos estaba obligado a tener consecuencias dramáticas. El mundo', -2.8181647658348083)]])
# INFO:argostranslate.utils:('hypotheses_to_return:', [('muchos y uno de ellos estaba obligado a tener consecuencias dramáticas. El mundo', -2.8181647658348083)])
# INFO:argostranslate.utils:('paragraphs:', ['entered a period of profound and painful readjustment which would mark the'])
# INFO:argostranslate.utils:('apply_packaged_translation', 'entered a period of profound and painful readjustment which would mark the')
# INFO:argostranslate.utils:('Splitting sentences using SBD Model: (en) StanzaSentencizer',)
# INFO:argostranslate.utils:('sentences', ['entered a period of profound and painful readjustment which would mark the'])
# INFO:argostranslate.utils:('tokenized', [['▁entered', '▁a', '▁period', '▁of', '▁profound', '▁and', '▁painful', '▁read', 'just', 'ment', '▁which', '▁would', '▁mark', '▁the']])
# INFO:argostranslate.utils:('translated_batches', [TranslationResult(hypotheses=[['▁entró', '▁en', '▁un', '▁período', '▁de', '▁profunda', '▁y', '▁dolorosa', '▁rea', 'just', 'e', '▁que', '▁marca', 'ría', '▁el']], scores=[-3.9476749897003174], attention=[], logits=[])])
# INFO:argostranslate.utils:('value_hypotheses:', [('entró en un período de profunda y dolorosa reajuste que marcaría el', -3.9476749897003174)])
# INFO:argostranslate.utils:('translated_paragraphs:', [[('entró en un período de profunda y dolorosa reajuste que marcaría el', -3.9476749897003174)]])
# INFO:argostranslate.utils:('hypotheses_to_return:', [('entró en un período de profunda y dolorosa reajuste que marcaría el', -3.9476749897003174)])
# INFO:argostranslate.utils:('paragraphs:', ['history of the twentieth century.'])
# INFO:argostranslate.utils:('apply_packaged_translation', 'history of the twentieth century.')
# INFO:argostranslate.utils:('Splitting sentences using SBD Model: (en) StanzaSentencizer',)
# INFO:argostranslate.utils:('sentences', ['history of the twentieth century.'])
# INFO:argostranslate.utils:('tokenized', [['▁history', '▁of', '▁the', '▁twentieth', '▁century', '.']])
# INFO:argostranslate.utils:('translated_batches', [TranslationResult(hypotheses=[['▁historia', '▁del', '▁siglo', '▁XX', '.']], scores=[-0.6636443734169006], attention=[], logits=[])])
# INFO:argostranslate.utils:('value_hypotheses:', [('historia del siglo XX.', -0.6636443734169006)])
# INFO:argostranslate.utils:('translated_paragraphs:', [[('historia del siglo XX.', -0.6636443734169006)]])
# INFO:argostranslate.utils:('hypotheses_to_return:', [('historia del siglo XX.', -0.6636443734169006)])
# INFO:argostranslate.utils:('paragraphs:', [''])
# INFO:argostranslate.utils:('apply_packaged_translation', '')
# INFO:argostranslate.utils:('Splitting sentences using SBD Model: (en) StanzaSentencizer',)
# INFO:argostranslate.utils:('sentences', [])
# INFO:argostranslate.utils:('tokenized', [])
# INFO:argostranslate.utils:('translated_batches', [])
# INFO:argostranslate.utils:('value_hypotheses:', [('', 0)])
# INFO:argostranslate.utils:('translated_paragraphs:', [[('', 0)]])
# INFO:argostranslate.utils:('hypotheses_to_return:', [('', 0)])
# ✅ Traducción guardada en: L1_A4_English_es.md
